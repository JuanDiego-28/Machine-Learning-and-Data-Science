# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../UNZIP_FOR_NOTEBOOKS_FINAL/DATA/bank-full.csv")

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
#check data 
plt.figure(figsize=(12,4) , dpi=200)
sns.histplot(data=df , x="age" , bins=30 , kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
#check data 
plt.figure(figsize=(12,4) , dpi=200)
sns.histplot(data=df , x="age" , bins=40 , hue="loan")
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
#check data 
plt.figure(figsize=(12,4) , dpi=200)
sns.histplot(data=df , x="pdays" , bins=40 )
# Out:
# <Axes: xlabel='pdays', ylabel='Count'>

# %%
#check data 
plt.figure(figsize=(12,4) , dpi=200)
sns.histplot(data=df , x="duration" , hue="contact")
plt.xlim(0,1700)
# Out:
# (0.0, 1700.0)

# %%
plt.figure(figsize=(12,4) , dpi=200)
sns.countplot(data=df, x="job" , order=df["job"].value_counts().index)
plt.xticks(rotation=90);

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
X = pd.get_dummies(df)

# %%
X
# Out:
#        age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0       56       261         1    999         0           1.1          93.994
# 1       57       149         1    999         0           1.1          93.994
# 2       37       226         1    999         0           1.1          93.994
# 3       40       151         1    999         0           1.1          93.994
# 4       56       307         1    999         0           1.1          93.994
# ...    ...       ...       ...    ...       ...           ...             ...
# 41183   73       334         1    999         0          -1.1          94.767
# 41184   46       383         1    999         0          -1.1          94.767
# 41185   56       189         2    999         0          -1.1          94.767
# 41186   44       442         1    999         0          -1.1          94.767
# 41187   74       239         3    999         1          -1.1          94.767
#
# ...

# %%
# scale the data 

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaled_X = scaler.fit_transform(X)

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=2)

# %%
cluster_labels = model.fit_predict(scaled_X)

# %%
cluster_labels
# Out:
# array([1, 1, 1, ..., 0, 0, 0], dtype=int32)

# %%
# assigning the labels 
X["Cluster"] = cluster_labels

# %%
X
# Out:
#        age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0       56       261         1    999         0           1.1          93.994
# 1       57       149         1    999         0           1.1          93.994
# 2       37       226         1    999         0           1.1          93.994
# 3       40       151         1    999         0           1.1          93.994
# 4       56       307         1    999         0           1.1          93.994
# ...    ...       ...       ...    ...       ...           ...             ...
# 41183   73       334         1    999         0          -1.1          94.767
# 41184   46       383         1    999         0          -1.1          94.767
# 41185   56       189         2    999         0          -1.1          94.767
# 41186   44       442         1    999         0          -1.1          94.767
# 41187   74       239         3    999         1          -1.1          94.767
#
# ...

# %%
plt.figure(figsize=(12,4) ,dpi=200)
X.corr()["Cluster"].iloc[:-1].sort_values().plot(kind="bar")
# Out:
# <Axes: >

# %%
# lets measure best clustering

ssd = []

for k in range(2,10):
    model = KMeans(n_clusters=k)
    model.fit(scaled_X)


    ssd.append(model.inertia_)  ## SSD POINT --> CLUSTER CENTER

# %%
ssd
# Out:
# [2469792.457107322,
#  2381344.461966297,
#  2335621.898085207,
#  2230963.1621824494,
#  2157781.324097727,
#  2081016.7865141712,
#  2098086.8097423664,
#  2077849.148591614]

# %%
plt.figure(figsize=(12,4) ,dpi=200)
plt.plot(range(2,10) , ssd , "o--")

# %%
pd.Series(ssd)  # calculate the diffferences with next and previous rows
# Out:
# 0    2.469792e+06
# 1    2.381344e+06
# 2    2.335622e+06
# 3    2.230963e+06
# 4    2.157781e+06
# 5    2.081017e+06
# 6    2.098087e+06
# 7    2.077849e+06
# dtype: float64

# %%
pd.Series(ssd).diff()
# Out:
# 0              NaN
# 1    -88447.995141
# 2    -45722.563881
# 3   -104658.735903
# 4    -73181.838085
# 5    -76764.537584
# 6     17070.023228
# 7    -20237.661151
# dtype: float64

# %% [markdown]
# #  Color quantization: Exerecise

# %%
import matplotlib.image as mpimg

# %%
image_array = mpimg.imread("../UNZIP_FOR_NOTEBOOKS_FINAL/DATA/palm_trees.jpg")

# %%
image_array.shape # (H,W,C)
# Out:
# (1401, 934, 3)

# %%
plt.imshow(image_array)

# %%
# flat the array

h,w,c = image_array.shape

image_2d = image_array.reshape(h*w, c)  # could use np.flatten

# %%
model = KMeans(n_clusters=6)

# %%
labels = model.fit_predict(image_2d)

# %%
#labels
# Out:
# array([2, 2, 2, ..., 1, 1, 1], dtype=int32)

# %%
rgb_codes = model.cluster_centers_.round(0).astype(int)  # round values

# %%
rgb_codes
# Out:
# array([[191, 154, 110],
#        [  3,   3,   4],
#        [ 71, 109, 138],
#        [219, 136,  47],
#        [137, 144, 144],
#        [ 67,  62,  62]])

# %%
q_image = np.reshape(rgb_codes[labels], (h,w,c))

# %%
plt.imshow(q_image)
