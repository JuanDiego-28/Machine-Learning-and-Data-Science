# %%
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import pandas as pd

# %%
df = pd.read_csv("../UNZIP_FOR_NOTEBOOKS_FINAL/DATA/Advertising.csv")

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %% [markdown]
# # REAMINDING : TRADITIONAL TRAIN|TEST SPLIT PROCEDURE

# %%
# preparing data 
X = df.drop("sales" , axis=1)
y = df["sales"]

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# Remember to scale data if required

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

# %%
# create the scaler instance

scaler = StandardScaler()
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
# fit the model 

from sklearn.linear_model import Ridge

# %%
model = Ridge(alpha=100)

# %%
model.fit(X_train, y_train)
# Out:
# Ridge(alpha=100)

# %%
y_pred = model.predict(X_test)

# %%
# Evaluate the model 

from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test , y_pred )
# Out:
# 7.341775789034128

# %%
# create another model 

model_two = Ridge(alpha=1)

# %%
model_two.fit(X_train, y_train)
# Out:
# Ridge(alpha=1)

# %%
y_pred_two = model_two.predict(X_test)

# %%
mean_squared_error(y_test , y_pred_two )
# Out:
# 2.3190215794287514

# %% [markdown]
# # TRAIN|VALIDATION|TEST_SPLIT

# %%
# First split 
X_train, X_other, y_train, y_other = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
# second split --> create validation and test split
X_eval, X_test, y_eval, y_test =  train_test_split(X_other, y_other , test_size=0.5, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train) 

X_eval = scaler.transform(X_eval)

X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import Ridge

model_three= Ridge(alpha=100)

# %%
model_three.fit(X_train , y_train)
# Out:
# Ridge(alpha=100)

# %%
y_eval_pre = model_three.predict(X_eval)

# %%
mean_squared_error(y_eval,y_eval_pre)
# Out:
# 7.320101458823871

# %%
# find a better fit 

model_three_one= Ridge(alpha=1)

# %%
model_three_one.fit(X_train , y_train)
model_three_one.fit(X_train , y_train)
y_eval_pre = model_three_one.predict(X_eval)

# %%
mean_squared_error(y_eval,y_eval_pre)
# Out:
# 2.383783075056986

# %%
# lets check out the final performance 

y_test_final = model_three_one.predict(X_test)

# %%
mean_squared_error(y_test,y_test_final)
# Out:
# 2.2542600838005176

# %% [markdown]
# # CROSS VALIDATION : CROSS_VAL_SCORE

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = Ridge(alpha=100)

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(model, X_train, y_train, scoring="neg_mean_squared_error" , cv=5)

# %%
abs(scores.mean())
# Out:
# 8.215396464543606

# %%
# improve model 

model1 = Ridge(alpha=1)
scores = cross_val_score(model1, X_train, y_train, scoring="neg_mean_squared_error" , cv=5)

# %%
abs(scores.mean())
# Out:
# 3.3448392965306946

# %%
model1.fit(X_train, y_train)
# Out:
# Ridge(alpha=1)

# %%
y_final = model1.predict(X_test)

# %%
mean_squared_error(y_test, y_final)
# Out:
# 2.3190215794287514

# %% [markdown]
# # CROSS_VALIDATE FUNCTION

# %%
# TRAIN TEST SPLIT
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# SCALING FUNCTION
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.model_selection import cross_validate

# %%
model = Ridge(alpha=100)

# %%
scores = cross_validate(model, X_train , y_train , scoring=["neg_mean_squared_error" , "neg_mean_absolute_error"] , cv=10)

# %%
scores = pd.DataFrame(scores)

# %%
scores
# Out:
#    fit_time  score_time  test_neg_mean_squared_error  \
# 0  0.002613    0.001652                    -6.060671
# 1  0.000997    0.000776                   -10.627031
# 2  0.002040    0.001864                    -3.993426
# 3  0.001451    0.001873                    -5.009494
# 4  0.002717    0.002727                    -9.141800
# 5  0.002196    0.001980                   -13.086256
# 6  0.002719    0.001629                    -3.839405
# 7  0.001173    0.001549                    -9.058786
# 8  0.003027    0.002324                    -9.055457
# 9  0.001593    0.001492                    -5.778882
#
#    test_neg_mean_absolute_error
# 0                     -1.810212
# 1                     -2.541958
# 2                     -1.469594
# 3                     -1.862769
# 4                     -2.520697
# 5                     -2.459995
# 6                     -1.451971
# 7                     -2.377395
# 8                     -2.443344
# 9                     -1.899797

# %%
scores.mean()
# Out:
# fit_time                        0.002052
# score_time                      0.001787
# test_neg_mean_squared_error    -7.565121
# test_neg_mean_absolute_error   -2.083773
# dtype: float64

# %%
# improve model 
model = Ridge(alpha=1)
scores = cross_validate(model, X_train , y_train , scoring=["neg_mean_squared_error" , "neg_mean_absolute_error"] , cv=10)

# %%
scores = pd.DataFrame(scores)

# %%
scores.mean()
# Out:
# fit_time                        0.001475
# score_time                      0.001424
# test_neg_mean_squared_error    -3.323018
# test_neg_mean_absolute_error   -1.308467
# dtype: float64

# %%
model.fit(X_train , y_train)
# Out:
# Ridge(alpha=1)

# %%
y_final = model.predict(X_test)

# %%
mean_squared_error(y_test, y_final)
# Out:
# 2.3190215794287514

# %% [markdown]
# # GRID SEARCH

# %%
# TRAIN TEST SPLIT
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# SCALING FUNCTION
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import ElasticNet

# %%
# create instance of net

base_elasticNet = ElasticNet()

# %%
param_grid = {"alpha": [0.1,1,5,10,50,100] , 
              "l1_ratio": [.1,.5,.7,.95,.99,1]}

# %%
# lets do grid search 

from sklearn.model_selection import GridSearchCV

# %%
grid_model = GridSearchCV(estimator=base_elasticNet , 
                          param_grid=param_grid, 
                          scoring="neg_mean_squared_error",
                          cv=5 , verbose=2)

# %%
grid_model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.7; total time=   0.0s
# ...

# %%
# check best parameters 
grid_model.best_estimator_
# Out:
# ElasticNet(alpha=0.1, l1_ratio=1)

# %%
grid_model.best_params_
# Out:
# {'alpha': 0.1, 'l1_ratio': 1}

# %%
pd.DataFrame(grid_model.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0        0.001736      0.000820         0.000853        0.000187         0.1
# 1        0.001663      0.000563         0.000903        0.000247         0.1
# 2        0.002530      0.000314         0.001294        0.000194         0.1
# 3        0.002201      0.000201         0.001061        0.000124         0.1
# 4        0.001844      0.000250         0.001051        0.000196         0.1
# 5        0.001202      0.000271         0.000573        0.000092         0.1
# 6        0.001590      0.000173         0.000722        0.000106           1
# 7        0.000932      0.000051         0.000525        0.000136           1
# 8        0.000987      0.000193         0.000609        0.000140           1
# 9        0.000718      0.000083         0.000436        0.000089           1
# 10       0.001075      0.000178         0.000575        0.000121           1
# ...

# %%
y_pred = grid_model.predict(X_test)

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 2.387342642087474
